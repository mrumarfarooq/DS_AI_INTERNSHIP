# %%
import pandas as pd

# %%
df=pd.read_csv("C:\DS_AI_Internship\src\customer_analytics.csv")

# %%
df
# Out:
#      CustomerID  Age  Gender       City  Education MaritalStatus  \
# 0          1001   49    Male       Pune    Masters        Single
# 1          1002   44    Male       Pune        PhD        Single
# 2          1003   42    Male     Mumbai  Bachelors        Single
# 3          1004   36  Female     Mumbai    Masters       Married
# 4          1005   23    Male       Pune    Masters       Married
# ..          ...  ...     ...        ...        ...           ...
# 250        1192   49    Male  Bangalore        PhD        Single
# 251        1157   35    Male  Hyderabad        PhD       Married
# 252        1223   40    Male     Mumbai    Masters       Married
# 253        1217   46  Female     Mumbai    Masters       Married
# 254        1206   32    Male      Delhi    Masters       Married
#
#      AnnualIncome  SpendingScore  YearsEmployed  PurchaseFrequency  \
# 0         82953.0             66             23                 19
# 1         60610.0             56             22                  1
# 2         35501.0             44             18                 10
# 3         99312.0             36             10                 12
# 4         46980.0             56              1                 18
# ..            ...            ...            ...                ...
# 250       58740.0             47             23                 18
# 251       50930.0             45             15                  5
# 252       79540.0              9             17                 13
# 253      102840.0             54             24                  2
# 254       60381.0             11             11                 11
#
#      OnlineVisitsPerMonth  ReturnedItems PreferredDevice  LastPurchaseAmount
# 0                       9              2          Laptop                3944
# 1                      23              3         Desktop                3885
# 2                      29              3          Laptop                3247
# 3                      21              3          Mobile                2028
# 4                       9              3          Tablet                1100
# ..                    ...            ...             ...                 ...
# 250                    14              1          Laptop                1161
# 251                    29              4          Mobile                4568
# 252                    17              4          Tablet                1743
# 253                    12              0          Tablet                1526
# 254                    29              1          Tablet                4812
#
# [255 rows x 14 columns]

# %%
df.head()
# Out:
#    CustomerID  Age  Gender    City  Education MaritalStatus  AnnualIncome  \
# 0        1001   49    Male    Pune    Masters        Single       82953.0
# 1        1002   44    Male    Pune        PhD        Single       60610.0
# 2        1003   42    Male  Mumbai  Bachelors        Single       35501.0
# 3        1004   36  Female  Mumbai    Masters       Married       99312.0
# 4        1005   23    Male    Pune    Masters       Married       46980.0
#
#    SpendingScore  YearsEmployed  PurchaseFrequency  OnlineVisitsPerMonth  \
# 0             66             23                 19                     9
# 1             56             22                  1                    23
# 2             44             18                 10                    29
# 3             36             10                 12                    21
# 4             56              1                 18                     9
#
#    ReturnedItems PreferredDevice  LastPurchaseAmount
# 0              2          Laptop                3944
# 1              3         Desktop                3885
# 2              3          Laptop                3247
# 3              3          Mobile                2028
# 4              3          Tablet                1100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            255 non-null    int64
#  1   Age                   255 non-null    int64
#  2   Gender                255 non-null    object
#  3   City                  255 non-null    object
#  4   Education             243 non-null    object
#  5   MaritalStatus         255 non-null    object
#  6   AnnualIncome          243 non-null    float64
#  7   SpendingScore         255 non-null    int64
#  8   YearsEmployed         255 non-null    int64
#  9   PurchaseFrequency     255 non-null    int64
#  10  OnlineVisitsPerMonth  255 non-null    int64
#  11  ReturnedItems         255 non-null    int64
#  12  PreferredDevice       255 non-null    object
#  13  LastPurchaseAmount    255 non-null    int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 28.0+ KB

# %%
df.describe()
# Out:
#         CustomerID         Age   AnnualIncome  SpendingScore  YearsEmployed  \
# count   255.000000  255.000000     243.000000     255.000000     255.000000
# mean   1126.941176   37.729412   74499.901235      45.721569      14.682353
# std      72.397256    9.767842   43939.855655      17.869522       9.651664
# min    1001.000000   21.000000   16062.000000       5.000000       1.000000
# 25%    1064.500000   29.000000   56353.000000      34.500000       6.000000
# 50%    1128.000000   38.000000   69629.000000      47.000000      15.000000
# 75%    1190.500000   46.000000   84030.500000      57.500000      23.000000
# max    1250.000000   54.000000  474327.000000      95.000000      34.000000
#
#        PurchaseFrequency  OnlineVisitsPerMonth  ReturnedItems  \
# count         255.000000            255.000000     255.000000
# mean           11.568627             16.078431       1.858824
# std             7.077899              7.909536       1.409917
# min             1.000000              3.000000       0.000000
# 25%             5.000000             10.000000       1.000000
# 50%            11.000000             16.000000       2.000000
# 75%            18.000000             23.000000       3.000000
# max            24.000000             29.000000       4.000000
#
#        LastPurchaseAmount
# count           255.00000
# mean           2795.07451
# std            1328.77241
# min             566.00000
# 25%            1542.50000
# 50%            2705.00000
# 75%            4001.00000
# max            4996.00000

# %%
df.isnull().sum()
# Out:
# CustomerID               0
# Age                      0
# Gender                   0
# City                     0
# Education               12
# MaritalStatus            0
# AnnualIncome            12
# SpendingScore            0
# YearsEmployed            0
# PurchaseFrequency        0
# OnlineVisitsPerMonth     0
# ReturnedItems            0
# PreferredDevice          0
# LastPurchaseAmount       0
# dtype: int64

# %%
#phase2

# %%
df['Education'].fillna(df['Education'].mode()[0],inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10024\3510158292.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Education'].fillna(df['Education'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID               0
# Age                      0
# Gender                   0
# City                     0
# Education                0
# MaritalStatus            0
# AnnualIncome            12
# SpendingScore            0
# YearsEmployed            0
# PurchaseFrequency        0
# OnlineVisitsPerMonth     0
# ReturnedItems            0
# PreferredDevice          0
# LastPurchaseAmount       0
# dtype: int64

# %%
df['AnnualIncome'].fillna(df['AnnualIncome'].median())
# Out:
# 0       82953.0
# 1       60610.0
# 2       35501.0
# 3       99312.0
# 4       46980.0
#          ...
# 250     58740.0
# 251     50930.0
# 252     79540.0
# 253    102840.0
# 254     60381.0
# Name: AnnualIncome, Length: 255, dtype: float64

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# City                    0
# Education               0
# MaritalStatus           0
# AnnualIncome            0
# SpendingScore           0
# YearsEmployed           0
# PurchaseFrequency       0
# OnlineVisitsPerMonth    0
# ReturnedItems           0
# PreferredDevice         0
# LastPurchaseAmount      0
# dtype: int64

# %%
#phase 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['AnnualIncome'],bins=20,kde=True)
plt.title("Anuual Income")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Education', data=df,color = "black")
plt.title("Distribution of Education Levels")
plt.xlabel("Education")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df["Age"], df["AnnualIncome"],color='black')
plt.xlabel("AGE")
plt.ylabel("Salary")
plt.title("AGE vs Salary Offered")
plt.show()

# %%
plt.boxplot(df["Age"])
plt.title("Box Plot of AGE")
plt.ylabel("AGE")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                       CustomerID       Age  AnnualIncome  SpendingScore  \
# CustomerID              1.000000 -0.030988     -0.035647       0.052029
# Age                    -0.030988  1.000000     -0.046527      -0.002351
# AnnualIncome           -0.035647 -0.046527      1.000000      -0.363641
# SpendingScore           0.052029 -0.002351     -0.363641       1.000000
# YearsEmployed          -0.011019  0.974985     -0.051115      -0.014257
# PurchaseFrequency      -0.079962  0.102801     -0.037357       0.006548
# OnlineVisitsPerMonth   -0.021931 -0.041306      0.105577      -0.085304
# ReturnedItems           0.021826 -0.056243     -0.121022       0.045469
# LastPurchaseAmount     -0.038018  0.076649     -0.024878       0.024245
#
#                       YearsEmployed  PurchaseFrequency  OnlineVisitsPerMonth  \
# CustomerID                -0.011019          -0.079962             -0.021931
# Age                        0.974985           0.102801             -0.041306
# AnnualIncome              -0.051115          -0.037357              0.105577
# SpendingScore             -0.014257           0.006548             -0.085304
# YearsEmployed              1.000000           0.070429             -0.056298
# PurchaseFrequency          0.070429           1.000000             -0.045245
# OnlineVisitsPerMonth      -0.056298          -0.045245              1.000000
# ReturnedItems             -0.054517           0.083035             -0.059726
# LastPurchaseAmount         0.101763          -0.072105              0.031448
#
#                       ReturnedItems  LastPurchaseAmount
# CustomerID                 0.021826           -0.038018
# Age                       -0.056243            0.076649
# AnnualIncome              -0.121022           -0.024878
# SpendingScore              0.045469            0.024245
# YearsEmployed             -0.054517            0.101763
# PurchaseFrequency          0.083035           -0.072105
# OnlineVisitsPerMonth      -0.059726            0.031448
# ReturnedItems              1.000000            0.023263
# LastPurchaseAmount         0.023263            1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, 
            annot=True, 
            cmap="coolwarm", 
            fmt=".2f",
            linewidths=0.5)

plt.title("Correlation Matrix Heatmap")
plt.show()
